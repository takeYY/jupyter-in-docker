# %%
# !pip install beautifulsoup4

# %%
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

novels = pd.read_csv('csv/edogawa_list.csv')

novels.head()
# Out:
#       name          file_name
# 0  赤いカブトムシ   akai_kabutomushi
# 1     赤い部屋          akai_heya
# 2    悪魔の紋章     akumano_monsho
# 3       悪霊             akuryo
# 4     悪霊物語  akuryo_monogatari

# %%
sakuhin_name = '怪人二十面相'
file_name = list(novels.query(' name == @sakuhin_name ')['file_name'])[0]

soup = BeautifulSoup(open(f'{file_name}_meishi_250.html'), 'html.parser')
#soup.h1.append(sakuhin_name)

#back_tag = soup.new_tag('a', href='../index.html', class_='container')
#soup.body.append(back_tag)
#soup.a.append('検索に戻る')

soup
# Out:
# <html>
# <head>
# <link href="https://cdnjs.cloudflare.com/ajax/libs/vis/4.16.1/vis.css" rel="stylesheet" type="text/css"/>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/vis/4.16.1/vis-network.min.js" type="text/javascript"> </script>
# <center>
# <h1></h1>
# </center>
# <!-- <link rel="stylesheet" href="../node_modules/vis/dist/vis.min.css" type="text/css" />
# <script type="text/javascript" src="../node_modules/vis/dist/vis.js"> </script>-->
# <style type="text/css">
#
#         #mynetwork {
#             width: 95%;
#             height: 1000px;
#             background-color: #222222;
#             border: 1px solid lightgray;
#             position: relative;
#             float: left;
#         }
#
#
#         #loadingBar {
#             position:absolute;
#             top:0px;
#             left:0px;
#             width: 95%;
#             height: 1000px;
#             background-color:rgba(200,200,200,0.8);
#             -webkit-transition: all 0.5s ease;
# ...

# %%
with open('static/test.html', mode = 'w', encoding = 'utf-8') as f:
    f.write(soup.prettify())
