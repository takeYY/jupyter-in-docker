# %%
import numpy as np
import pandas as pd
import itertools
import collections
import time

novels = pd.read_csv('csv/edogawa_list.csv')
novels
# Out:
#     reader_id     name          file_name  original_text      publisher  \
# 0       57105  赤いカブトムシ   akai_kabutomushi            新宝島  江戸川乱歩推理文庫、講談社
# 1       57181     赤い部屋          akai_heya    江戸川乱歩全集　第七巻            平凡社
# 2       57240    悪魔の紋章     akumano_monsho    江戸川乱歩選集　第二巻            新潮社
# 3       57515       悪霊             akuryo            新青年            博文館
# 4       58699     悪霊物語  akuryo_monogatari   江戸川乱歩全集　第十六巻            春陽堂
# ..        ...      ...                ...            ...            ...
# 90      58465        指               yubi    江戸川乱歩全集　第三巻            桃源社
# 91      57197       指環             yubiwa    江戸川乱歩全集　第九巻            平凡社
# 92      56670     妖怪博士       yokai_hakase     妖怪博士／青銅の魔人  江戸川乱歩推理文庫、講談社
# 93      56681    妖人ゴング        yojin_gongu      黄金豹／妖人ゴング  江戸川乱歩推理文庫、講談社
# 94      56691     妖星人R         yoseijin_r  おれは二十面相だ／妖星人Ｒ  江戸川乱歩推理文庫、講談社
#
#     published_date                          first_appearance
# 0        1988-11-8  「たのしい三年生」講談社、1958（昭和33）年4月～1959（昭和34）年3月
# 1          1931-12                    「新青年」博文館、1925（大正14）年4月
# 2          1938-10    「日の出」新潮社、1937（昭和12）年10月～1938（昭和13）年10月
# 3   1933-11～1934-1       「新青年」博文館、1933（昭和8）年11月～1934（昭和9）年1月
# 4          1955-12                「講談倶楽部」講談社、1954（昭和29）年9月増刊
# ..             ...                                       ...
# 90         1961-11            「ヒッチコック　マガジン」宝石社、1960（昭和35）年1月
# 91          1932-3                    「新青年」博文館、1925（大正14）年7月
# 92       1987-11-6      「少年倶楽部」大日本雄辯會講談社、1938（昭和13）年1月号～12月号
# 93        1988-4-8               「少年」光文社、1957（昭和32）年1月号～12月号
# 94        1988-9-8           「少年」光文社、1961（昭和36）年1月～3月、5月～12月
#
# [95 rows x 7 columns]

# %%
novels.name
# Out:
# 0     赤いカブトムシ
# 1        赤い部屋
# 2       悪魔の紋章
# 3          悪霊
# 4        悪霊物語
#        ...
# 90          指
# 91         指環
# 92       妖怪博士
# 93      妖人ゴング
# 94       妖星人R
# Name: name, Length: 95, dtype: object

# %%
for name, file in novels[['name', 'file_name']].values:
    print(f'name:{name}, file: {file}')
# Out:
# name:赤いカブトムシ, file: akai_kabutomushi
# name:赤い部屋, file: akai_heya
# name:悪魔の紋章, file: akumano_monsho
# name:悪霊, file: akuryo
# name:悪霊物語, file: akuryo_monogatari
# name:「悪霊物語」自作解説, file: akuryo_monogatari_jisaku_kaisetsu
# name:一枚の切符, file: ichimaino_kippu
# name:一寸法師, file: issunboshi
# name:宇宙怪人, file: uchu_kaijin
# name:江川蘭子, file: egawa_ranko
# name:黄金豹, file: ogon_hyo
# name:押絵と旅する男, file: oshieto_tabisuru_otoko
# name:お勢登場, file: osei_tojo
# name:恐ろしき錯誤, file: osoroshiki_sakugo
# name:踊る一寸法師, file: odoru_issun_boshi
# name:鬼, file: oni
# name:俺は二十面相だ, file: orewa_nijumensoda
# name:怪奇四十面相, file: kaiki_yonju_menso
# name:怪人と少年探偵, file: kaijinto_shonen_tantei
# name:かいじん二十めんそう_1, file: kaijin_nijumenso_57226
# name:かいじん二十めんそう_2, file: kaijin_nijumenso_57227
# name:怪人二十面相, file: kaijin_nijumenso
# name:海底の魔術師, file: kaiteino_majutsushi
# name:鏡地獄, file: kagami_jigoku
# name:影男, file: kageotoko
# name:火星の運河, file: kaseino_unga
# name:仮面の恐怖王, file: kamenno_kyofuo
# name:奇面城の秘密, file: kimenjono_himitsu
# name:吸血鬼, file: kyuketsuki
# name:恐怖王, file: kyofu_o
# name:疑惑, file: giwaku
# name:黒手組, file: kurote_gumi
# name:黒蜥蜴, file: kurotokage
# name:五階の窓, file: gokaino_mado_01
# name:孤島の鬼, file: kotono_oni
# name:湖畔亭事件, file: kohantei_jiken
# name:サーカスの怪人, file: sakasuno_kaijin
# name:殺人迷路, file: satsujin_meiro_05
# name:自作解説（怪人二十面相と少年探偵団）, file: jisaku_kaisetsu_kaijin_nijumenso
# name:少年探偵団, file: shonen_tanteidan
# name:心理試験, file: shinri_shiken
# name:随筆銭形平次, file: 19tanteishosetsu_konogoro
# name:青銅の魔人, file: seidono_majin
# name:接吻, file: seppun
# name:双生児, file: soseiji
# name:算盤が恋を語る話, file: sorobanga_koio_kataru_hanashi
# name:大金塊, file: dai_kinkai
# name:断崖, file: dangai
# name:探偵小説の「謎」, file: tantei_shosetsuno_nazo
# name:探偵少年, file: tantei_shonen
# name:超人ニコラ, file: chojin_nikora
# name:月と手袋, file: tsukito_tebukuro
# name:妻に失恋した男, file: tsumani_shitsuren_shita_otoko
# name:D坂の殺人事件, file: d_zakano_satsujin_jiken
# name:鉄人Q, file: tetsujin_kyu
# name:鉄塔の怪人, file: tettono_kaijin
# name:天空の魔人, file: tenkuno_majin
# name:電人M, file: denjin_emu
# name:塔上の奇術師, file: tojono_kijutsushi
# name:盗難, file: tonan
# name:透明怪人, file: tomei_kaijin
# name:毒草, file: dokuso
# name:虎の牙, file: torano_kiba
# name:何者, file: nanimono
# name:二銭銅貨, file: nisen_doka
# name:日記帳, file: nikkicho
# name:二癈人, file: nihaijin
# name:人間椅子, file: ningen_isu
# name:人間豹, file: ningen_hyo
# name:灰色の巨人, file: haiirono_kyojin
# name:灰神楽, file: haikagura
# name:白昼夢, file: hakuchumu
# name:パノラマ島綺譚, file: panoramato_kidan
# name:人でなしの恋, file: hitodenashino_koi
# name:一人の芭蕉の問題, file: hitorino_bashono_mondai
# name:一人二役, file: hitori_futayaku
# name:火縄銃, file: hinawaju
# name:百面相役者, file: hyakumenso_yakusha
# name:覆面の舞踏者, file: fukumenno_butosha
# name:ふしぎな人, file: fushigina_hito
# name:魔法人形, file: maho_ningyo
# name:魔法博士, file: maho_hakase
# name:まほうやしき, file: maho_yashiki
# name:夢遊病者の死, file: muyubyoshano_shi
# name:目羅博士の不思議な犯罪, file: mera_hakaseno_fushigina_hanzai
# name:木馬は廻る, file: mokubawa_mawaru
# name:モノグラム, file: monoguramu
# name:夜光人間, file: yako_ningen
# name:屋根裏の散歩者, file: yaneurano_sanposha
# name:幽霊, file: yurei
# name:指, file: yubi
# name:指環, file: yubiwa
# name:妖怪博士, file: yokai_hakase
# name:妖人ゴング, file: yojin_gongu
# name:妖星人R, file: yoseijin_r

# %%
sakuhin_name = '怪人二十面相'
target_hinshi = ['名詞', '形容詞', '動詞', '副詞']
hinshi_name = ''
target_num = 250

#"""
if '' in target_hinshi in ['名詞']:
    hinshi_name = 'meishi'
elif target_hinshi == ['形容詞']:
    hinshi_name = 'keiyoushi'
elif target_hinshi == ['副詞']:
    hinshi_name = 'fukushi'
elif target_hinshi == ['動詞']:
    hinshi_name = 'doushi'
else:
    hinshi_name = 'all'
### """

file_name = list(novels.query(' name == @sakuhin_name ')['file_name'])[0]
df = pd.read_csv(f'csv/df/{file_name}.csv')

# %%
# """
midashi = list(df['見出し'])
genkei = list(df['原型'])
hinshi = list(df['品詞'])
sentences = []
for i in range(len(midashi)):
    sentences.append([midashi[i], genkei[i], hinshi[i]])

keywords = []
words = []
for sentence in sentences:
    if sentence[0] != '。':
        if sentence[2] in target_hinshi:
            words.append(sentence[1])
    else:
        keywords.append(words)
        words = []

sentence_combinations = [list(itertools.combinations(set(sentence), 2)) for sentence in keywords]
sentence_combinations = [[tuple(sorted(words)) for words in sentence] for sentence in sentence_combinations]
target_combinations = []
for sentence in sentence_combinations:
    target_combinations.extend(sentence)

target_combinations
### """
# Out:
# [('天気', '東京'),
#  ('いう', '天気'),
#  ('天気', '怪人'),
#  ('する', '天気'),
#  ('天気', '家'),
#  ('天気', '顔'),
#  ('天気', '町'),
#  ('人', '天気'),
#  ('まるで', '天気'),
#  ('天気', '面相'),
#  ('ふた', '天気'),
#  ('そのころ', '天気'),
#  ('二十', '天気'),
#  ('うわさ', '天気'),
#  ('あいさつ', '天気'),
#  ('あわせる', '天気'),
#  ('いう', '東京'),
#  ('怪人', '東京'),
#  ('する', '東京'),
#  ('家', '東京'),
#  ('東京', '顔'),
#  ('東京', '町'),
#  ('人', '東京'),
#  ('まるで', '東京'),
#  ('東京', '面相'),
#  ('ふた', '東京'),
#  ('そのころ', '東京'),
#  ('二十', '東京'),
#  ('うわさ', '東京'),
#  ('あいさつ', '東京'),
#  ('あわせる', '東京'),
#  ('いう', '怪人'),
#  ('いう', 'する'),
#  ('いう', '家'),
#  ('いう', '顔'),
#  ('いう', '町'),
#  ('いう', '人'),
#  ('いう', 'まるで'),
#  ('いう', '面相'),
#  ('いう', 'ふた'),
#  ('いう', 'そのころ'),
#  ('いう', '二十'),
#  ('いう', 'うわさ'),
#  ('あいさつ', 'いう'),
#  ('あわせる', 'いう'),
#  ('する', '怪人'),
#  ('家', '怪人'),
#  ('怪人', '顔'),
#  ('怪人', '町'),
#  ('人', '怪人'),
#  ('まるで', '怪人'),
#  ('怪人', '面相'),
#  ('ふた', '怪人'),
#  ('そのころ', '怪人'),
#  ('二十', '怪人'),
#  ('うわさ', '怪人'),
#  ('あいさつ', '怪人'),
#  ('あわせる', '怪人'),
#  ('する', '家'),
#  ('する', '顔'),
#  ('する', '町'),
#  ('する', '人'),
#  ('する', 'まるで'),
#  ('する', '面相'),
#  ('する', 'ふた'),
#  ('する', 'そのころ'),
#  ('する', '二十'),
#  ('うわさ', 'する'),
#  ('あいさつ', 'する'),
#  ('あわせる', 'する'),
#  ('家', '顔'),
#  ('家', '町'),
#  ('人', '家'),
#  ('まるで', '家'),
#  ('家', '面相'),
#  ('ふた', '家'),
#  ('そのころ', '家'),
#  ('二十', '家'),
#  ('うわさ', '家'),
#  ('あいさつ', '家'),
#  ('あわせる', '家'),
#  ('町', '顔'),
#  ('人', '顔'),
#  ('まるで', '顔'),
#  ('面相', '顔'),
#  ('ふた', '顔'),
#  ('そのころ', '顔'),
#  ('二十', '顔'),
#  ('うわさ', '顔'),
#  ('あいさつ', '顔'),
#  ('あわせる', '顔'),
#  ('人', '町'),
#  ('まるで', '町'),
#  ('町', '面相'),
#  ('ふた', '町'),
#  ('そのころ', '町'),
#  ('二十', '町'),
#  ('うわさ', '町'),
#  ('あいさつ', '町'),
#  ('あわせる', '町'),
#  ('まるで', '人'),
#  ('人', '面相'),
#  ('ふた', '人'),
#  ('そのころ', '人'),
#  ('二十', '人'),
#  ('うわさ', '人'),
#  ('あいさつ', '人'),
#  ('あわせる', '人'),
#  ('まるで', '面相'),
#  ('ふた', 'まるで'),
#  ('そのころ', 'まるで'),
#  ('まるで', '二十'),
#  ('うわさ', 'まるで'),
#  ('あいさつ', 'まるで'),
#  ('あわせる', 'まるで'),
#  ('ふた', '面相'),
#  ('そのころ', '面相'),
#  ('二十', '面相'),
#  ('うわさ', '面相'),
#  ('あいさつ', '面相'),
#  ('あわせる', '面相'),
#  ('そのころ', 'ふた'),
#  ('ふた', '二十'),
#  ('うわさ', 'ふた'),
#  ('あいさつ', 'ふた'),
#  ('あわせる', 'ふた'),
#  ('そのころ', '二十'),
#  ('うわさ', 'そのころ'),
#  ('あいさつ', 'そのころ'),
#  ('あわせる', 'そのころ'),
#  ('うわさ', '二十'),
#  ('あいさつ', '二十'),
#  ('あわせる', '二十'),
#  ('あいさつ', 'うわさ'),
#  ('あわせる', 'うわさ'),
#  ('あいさつ', 'あわせる'),
#  ('いう', '新聞'),
#  ('新聞', '毎日'),
#  ('の', '新聞'),
#  ('新聞', '盗賊'),
#  ('ふしぎだ', '新聞'),
#  ('新聞', '記事'),
#  ('あだ名', '新聞'),
#  ('にぎわす', '新聞'),
#  ('新聞', '面相'),
#  ('二十', '新聞'),
#  ('いう', '毎日'),
#  ('いう', 'の'),
#  ('いう', '盗賊'),
#  ('いう', 'ふしぎだ'),
#  ('いう', '記事'),
#  ('あだ名', 'いう'),
#  ('いう', 'にぎわす'),
#  ('いう', '面相'),
#  ('いう', '二十'),
#  ('の', '毎日'),
#  ('毎日', '盗賊'),
#  ('ふしぎだ', '毎日'),
#  ('毎日', '記事'),
#  ('あだ名', '毎日'),
#  ('にぎわす', '毎日'),
#  ('毎日', '面相'),
#  ('二十', '毎日'),
#  ('の', '盗賊'),
#  ('の', 'ふしぎだ'),
#  ('の', '記事'),
#  ('あだ名', 'の'),
#  ('にぎわす', 'の'),
#  ('の', '面相'),
#  ('の', '二十'),
#  ('ふしぎだ', '盗賊'),
#  ('盗賊', '記事'),
#  ('あだ名', '盗賊'),
#  ('にぎわす', '盗賊'),
#  ('盗賊', '面相'),
#  ('二十', '盗賊'),
#  ('ふしぎだ', '記事'),
#  ('あだ名', 'ふしぎだ'),
#  ('にぎわす', 'ふしぎだ'),
#  ('ふしぎだ', '面相'),
#  ('ふしぎだ', '二十'),
#  ('あだ名', '記事'),
#  ('にぎわす', '記事'),
#  ('記事', '面相'),
#  ('二十', '記事'),
#  ('あだ名', 'にぎわす'),
#  ('あだ名', '面相'),
#  ('あだ名', '二十'),
#  ('にぎわす', '面相'),
#  ('にぎわす', '二十'),
#  ('二十', '面相'),
#  ('いう', '賊'),
#  ('持つ', '賊'),
#  ('賊', '顔'),
#  ('まったく', '賊'),
#  ('ちがう', '賊'),
#  ('二十', '賊'),
#  ('いう', '持つ'),
#  ('いう', '顔'),
#  ('いう', 'まったく'),
#  ('いう', 'ちがう'),
#  ('いう', '二十'),
#  ('持つ', '顔'),
#  ('まったく', '持つ'),
#  ('ちがう', '持つ'),
#  ('二十', '持つ'),
#  ('まったく', '顔'),
#  ('ちがう', '顔'),
#  ('二十', '顔'),
#  ('ちがう', 'まったく'),
#  ('まったく', '二十'),
#  ('ちがう', '二十'),
#  ('とびきり', '変装'),
#  ('じょうずだ', 'とびきり'),
#  ('つまり', 'とびきり'),
#  ('じょうずだ', '変装'),
#  ('つまり', '変装'),
#  ('じょうずだ', 'つまり'),
#  ('ながめる', '近よる'),
#  ('場所', '近よる'),
#  ('変装', '近よる'),
#  ('見える', '近よる'),
#  ('わかる', '近よる'),
#  ('まるで', '近よる'),
#  ('ちがう', '近よる'),
#  ('人', '近よる'),
#  ('少しも', '近よる'),
#  ('明るい', '近よる'),
#  ('ながめる', '場所'),
#  ('ながめる', '変装'),
#  ('ながめる', '見える'),
#  ('ながめる', 'わかる'),
#  ('ながめる', 'まるで'),
#  ('ちがう', 'ながめる'),
#  ('ながめる', '人'),
#  ('ながめる', '少しも'),
#  ('ながめる', '明るい'),
#  ('場所', '変装'),
#  ('場所', '見える'),
#  ('わかる', '場所'),
#  ('まるで', '場所'),
#  ('ちがう', '場所'),
#  ('人', '場所'),
#  ('場所', '少しも'),
#  ('場所', '明るい'),
#  ('変装', '見える'),
#  ('わかる', '変装'),
#  ('まるで', '変装'),
#  ('ちがう', '変装'),
#  ('人', '変装'),
#  ('変装', '少しも'),
#  ('変装', '明るい'),
#  ('わかる', '見える'),
#  ('まるで', '見える'),
#  ('ちがう', '見える'),
#  ('人', '見える'),
#  ('少しも', '見える'),
#  ('明るい', '見える'),
#  ('まるで', 'わかる'),
#  ('ちがう', 'わかる'),
#  ('わかる', '人'),
#  ('わかる', '少しも'),
#  ('わかる', '明るい'),
#  ('ちがう', 'まるで'),
#  ('まるで', '人'),
#  ('まるで', '少しも'),
#  ('まるで', '明るい'),
#  ('ちがう', '人'),
#  ('ちがう', '少しも'),
#  ('ちがう', '明るい'),
#  ('人', '少しも'),
#  ('人', '明るい'),
#  ('少しも', '明るい'),
#  ('できる', '富豪'),
#  ('できる', '乞食'),
#  ('いう', 'できる'),
#  ('できる', '老人'),
#  ('できる', '女'),
#  ('できる', 'なりきる'),
#  ('できる', '学者'),
#  ('できる', 'まったく'),
#  ('こと', 'できる'),
#  ('できる', '人'),
#  ('できる', '無頼漢'),
#  ('できる', '若者'),
#  ('乞食', '富豪'),
#  ('いう', '富豪'),
#  ('富豪', '老人'),
#  ('女', '富豪'),
#  ('なりきる', '富豪'),
#  ('学者', '富豪'),
#  ('まったく', '富豪'),
#  ('こと', '富豪'),
#  ('人', '富豪'),
#  ('富豪', '無頼漢'),
#  ('富豪', '若者'),
#  ('いう', '乞食'),
#  ('乞食', '老人'),
#  ('乞食', '女'),
#  ('なりきる', '乞食'),
#  ('乞食', '学者'),
#  ('まったく', '乞食'),
#  ('こと', '乞食'),
#  ('乞食', '人'),
#  ('乞食', '無頼漢'),
#  ('乞食', '若者'),
#  ('いう', '老人'),
#  ('いう', '女'),
#  ('いう', 'なりきる'),
#  ('いう', '学者'),
#  ('いう', 'まったく'),
#  ('いう', 'こと'),
#  ('いう', '人'),
#  ('いう', '無頼漢'),
#  ('いう', '若者'),
#  ('女', '老人'),
#  ('なりきる', '老人'),
#  ('学者', '老人'),
#  ('まったく', '老人'),
#  ('こと', '老人'),
#  ('人', '老人'),
#  ('無頼漢', '老人'),
#  ('老人', '若者'),
#  ('なりきる', '女'),
#  ('女', '学者'),
#  ('まったく', '女'),
#  ('こと', '女'),
#  ('人', '女'),
#  ('女', '無頼漢'),
#  ('女', '若者'),
#  ('なりきる', '学者'),
#  ('なりきる', 'まったく'),
#  ('こと', 'なりきる'),
#  ('なりきる', '人'),
#  ('なりきる', '無頼漢'),
#  ('なりきる', '若者'),
#  ('まったく', '学者'),
#  ('こと', '学者'),
#  ('人', '学者'),
#  ('学者', '無頼漢'),
#  ('学者', '若者'),
#  ('こと', 'まったく'),
#  ('まったく', '人'),
#  ('まったく', '無頼漢'),
#  ('まったく', '若者'),
#  ('こと', '人'),
#  ('こと', '無頼漢'),
#  ('こと', '若者'),
#  ('人', '無頼漢'),
#  ('人', '若者'),
#  ('無頼漢', '若者'),
#  ('いう', '賊'),
#  ('する', '賊'),
#  ('見る', '賊'),
#  ('だれひとり', '賊'),
#  ('ある', '賊'),
#  ('いく', '賊'),
#  ('賊', '顔'),
#  ('こと', '賊'),
#  ('年', '賊'),
#  ('ほんとうだ', '賊'),
#  ('いう', 'する'),
#  ('いう', '見る'),
#  ('いう', 'だれひとり'),
#  ('ある', 'いう'),
#  ('いう', 'いく'),
#  ('いう', '顔'),
#  ('いう', 'こと'),
#  ('いう', '年'),
#  ('いう', 'ほんとうだ'),
#  ('する', '見る'),
#  ('する', 'だれひとり'),
#  ('ある', 'する'),
#  ('いく', 'する'),
#  ('する', '顔'),
#  ('こと', 'する'),
#  ('する', '年'),
#  ('する', 'ほんとうだ'),
#  ('だれひとり', '見る'),
#  ('ある', '見る'),
#  ('いく', '見る'),
#  ('見る', '顔'),
#  ('こと', '見る'),
#  ('年', '見る'),
#  ('ほんとうだ', '見る'),
#  ('ある', 'だれひとり'),
#  ('いく', 'だれひとり'),
#  ('だれひとり', '顔'),
#  ('こと', 'だれひとり'),
#  ('だれひとり', '年'),
#  ('だれひとり', 'ほんとうだ'),
#  ('ある', 'いく'),
#  ('ある', '顔'),
#  ('ある', 'こと'),
#  ('ある', '年'),
#  ('ある', 'ほんとうだ'),
#  ('いく', '顔'),
#  ('いく', 'こと'),
#  ('いく', '年'),
#  ('いく', 'ほんとうだ'),
#  ('こと', '顔'),
#  ('年', '顔'),
#  ('ほんとうだ', '顔'),
#  ('こと', '年'),
#  ('こと', 'ほんとうだ'),
#  ('ほんとうだ', '年'),
#  ('だれ', '知る'),
#  ('だれ', '持つ'),
#  ('だれ', '顔'),
#  ('だれ', '種'),
#  ('そのうち', 'だれ'),
#  ('だれ', '二十'),
#  ('だれ', 'ほんとうだ'),
#  ('持つ', '知る'),
#  ('知る', '顔'),
#  ('知る', '種'),
#  ('そのうち', '知る'),
#  ('二十', '知る'),
#  ('ほんとうだ', '知る'),
#  ('持つ', '顔'),
#  ('持つ', '種'),
#  ('そのうち', '持つ'),
#  ('二十', '持つ'),
#  ('ほんとうだ', '持つ'),
#  ('種', '顔'),
#  ('そのうち', '顔'),
#  ('二十', '顔'),
#  ('ほんとうだ', '顔'),
#  ('そのうち', '種'),
#  ('二十', '種'),
#  ('ほんとうだ', '種'),
#  ('そのうち', '二十'),
#  ('そのうち', 'ほんとうだ'),
#  ('ほんとうだ', '二十'),
#  ('わすれる', '賊'),
#  ('賊', '顔'),
#  ('しれる', '賊'),
#  ('ほんとうだ', '賊'),
#  ('自身', '賊'),
#  ('わすれる', '顔'),
#  ('しれる', 'わすれる'),
#  ('ほんとうだ', 'わすれる'),
#  ('わすれる', '自身'),
#  ('しれる', '顔'),
#  ('ほんとうだ', '顔'),
#  ('自身', '顔'),
#  ('しれる', 'ほんとうだ'),
#  ('しれる', '自身'),
#  ('ほんとうだ', '自身'),
#  ('それほど', '姿'),
#  ('それほど', '顔'),
#  ('それほど', '人'),
#  ('それほど', 'ちがう'),
#  ('それほど', 'たえず'),
#  ('あらわれる', 'それほど'),
#  ('それほど', '前'),
#  ('姿', '顔'),
#  ('人', '姿'),
#  ('ちがう', '姿'),
#  ('たえず', '姿'),
#  ('あらわれる', '姿'),
#  ('前', '姿'),
#  ('人', '顔'),
#  ('ちがう', '顔'),
#  ('たえず', '顔'),
#  ('あらわれる', '顔'),
#  ('前', '顔'),
#  ('ちがう', '人'),
#  ('たえず', '人'),
#  ('あらわれる', '人'),
#  ('人', '前'),
#  ('たえず', 'ちがう'),
#  ('あらわれる', 'ちがう'),
#  ('ちがう', '前'),
#  ('あらわれる', 'たえず'),
#  ('たえず', '前'),
#  ('あらわれる', '前'),
#  ('天才', '賊'),
#  ('変装', '天才'),
#  ('天才', '警察'),
#  ('こまる', '天才'),
#  ('もの', '天才'),
#  ('変装', '賊'),
#  ('警察', '賊'),
#  ('こまる', '賊'),
#  ('もの', '賊'),
#  ('変装', '警察'),
#  ('こまる', '変装'),
#  ('もの', '変装'),
#  ('こまる', '警察'),
#  ('もの', '警察'),
#  ('こまる', 'もの'),
#  ('いい', 'いったい'),
#  ('いったい', '目'),
#  ('いったい', '顔'),
#  ('いったい', 'つく'),
#  ('いったい', 'まるで'),
#  ('いったい', '捜索'),
#  ('いったい', '見当'),
#  ('いったい', 'する'),
#  ('いい', '目'),
#  ('いい', '顔'),
#  ('いい', 'つく'),
#  ('いい', 'まるで'),
#  ('いい', '捜索'),
#  ('いい', '見当'),
#  ('いい', 'する'),
#  ('目', '顔'),
#  ('つく', '目'),
#  ('まるで', '目'),
#  ('捜索', '目'),
#  ('目', '見当'),
#  ('する', '目'),
#  ('つく', '顔'),
#  ('まるで', '顔'),
#  ('捜索', '顔'),
#  ('見当', '顔'),
#  ('する', '顔'),
#  ('つく', 'まるで'),
#  ('つく', '捜索'),
#  ('つく', '見当'),
#  ('する', 'つく'),
#  ('まるで', '捜索'),
#  ('まるで', '見当'),
#  ('する', 'まるで'),
#  ('捜索', '見当'),
#  ('する', '捜索'),
#  ('する', '見当'),
#  ('一', '人'),
#  ('人', '高価だ'),
#  ('人', '興味'),
#  ('ふるまい', '人'),
#  ('人', '美術'),
#  ('人', '盗賊'),
#  ('ざんこくだ', '人'),
#  ('人', '傷つける'),
#  ('ある', '人'),
#  ('ぬすむ', '人'),
#  ('めずらしい', '人'),
#  ('人', '現金'),
#  ('あまり', '人'),
#  ('せめても', '人'),
#  ('人', '殺す'),
#  ('こと', '人'),
#  ('する', '人'),
#  ('人', '宝石'),
#  ('しあわせだ', '人'),
#  ('人', '持つ'),
#  ('ひじょうだ', '人'),
#  ('ただ', '人'),
#  ('人', '美しい'),
#  ('人', '品'),
#  ('人', '品物'),
#  ('一', '高価だ'),
#  ('一', '興味'),
#  ('ふるまい', '一'),
#  ('一', '美術'),
#  ('一', '盗賊'),
#  ('ざんこくだ', '一'),
#  ('一', '傷つける'),
#  ('ある', '一'),
#  ('ぬすむ', '一'),
#  ('めずらしい', '一'),
#  ('一', '現金'),
#  ('あまり', '一'),
#  ('せめても', '一'),
#  ('一', '殺す'),
#  ('こと', '一'),
#  ('する', '一'),
#  ('一', '宝石'),
#  ('しあわせだ', '一'),
#  ('一', '持つ'),
#  ('ひじょうだ', '一'),
#  ('ただ', '一'),
#  ('一', '美しい'),
#  ('一', '品'),
#  ('一', '品物'),
#  ('興味', '高価だ'),
#  ('ふるまい', '高価だ'),
#  ('美術', '高価だ'),
#  ('盗賊', '高価だ'),
#  ('ざんこくだ', '高価だ'),
#  ('傷つける', '高価だ'),
#  ('ある', '高価だ'),
#  ('ぬすむ', '高価だ'),
#  ('めずらしい', '高価だ'),
#  ('現金', '高価だ'),
#  ('あまり', '高価だ'),
#  ('せめても', '高価だ'),
#  ('殺す', '高価だ'),
#  ('こと', '高価だ'),
#  ('する', '高価だ'),
#  ('宝石', '高価だ'),
#  ('しあわせだ', '高価だ'),
#  ('持つ', '高価だ'),
#  ('ひじょうだ', '高価だ'),
#  ('ただ', '高価だ'),
#  ('美しい', '高価だ'),
#  ('品', '高価だ'),
#  ('品物', '高価だ'),
#  ('ふるまい', '興味'),
#  ('美術', '興味'),
#  ('盗賊', '興味'),
#  ('ざんこくだ', '興味'),
#  ('傷つける', '興味'),
#  ('ある', '興味'),
#  ('ぬすむ', '興味'),
#  ('めずらしい', '興味'),
#  ('現金', '興味'),
#  ('あまり', '興味'),
#  ('せめても', '興味'),
#  ('殺す', '興味'),
#  ('こと', '興味'),
#  ('する', '興味'),
#  ('宝石', '興味'),
#  ('しあわせだ', '興味'),
#  ('持つ', '興味'),
#  ('ひじょうだ', '興味'),
#  ('ただ', '興味'),
#  ('美しい', '興味'),
#  ('品', '興味'),
#  ('品物', '興味'),
#  ('ふるまい', '美術'),
#  ('ふるまい', '盗賊'),
#  ('ざんこくだ', 'ふるまい'),
#  ('ふるまい', '傷つける'),
#  ('ある', 'ふるまい'),
#  ('ぬすむ', 'ふるまい'),
#  ('ふるまい', 'めずらしい'),
#  ('ふるまい', '現金'),
#  ('あまり', 'ふるまい'),
#  ('せめても', 'ふるまい'),
#  ('ふるまい', '殺す'),
#  ('こと', 'ふるまい'),
#  ('する', 'ふるまい'),
#  ('ふるまい', '宝石'),
#  ('しあわせだ', 'ふるまい'),
#  ('ふるまい', '持つ'),
#  ('ひじょうだ', 'ふるまい'),
#  ('ただ', 'ふるまい'),
#  ('ふるまい', '美しい'),
#  ('ふるまい', '品'),
#  ('ふるまい', '品物'),
#  ('盗賊', '美術'),
#  ('ざんこくだ', '美術'),
#  ('傷つける', '美術'),
#  ('ある', '美術'),
#  ('ぬすむ', '美術'),
#  ('めずらしい', '美術'),
#  ('現金', '美術'),
#  ('あまり', '美術'),
#  ('せめても', '美術'),
#  ('殺す', '美術'),
#  ('こと', '美術'),
#  ('する', '美術'),
#  ('宝石', '美術'),
#  ('しあわせだ', '美術'),
#  ('持つ', '美術'),
#  ('ひじょうだ', '美術'),
#  ('ただ', '美術'),
#  ('美しい', '美術'),
#  ('品', '美術'),
#  ('品物', '美術'),
#  ('ざんこくだ', '盗賊'),
#  ('傷つける', '盗賊'),
#  ('ある', '盗賊'),
#  ('ぬすむ', '盗賊'),
#  ('めずらしい', '盗賊'),
#  ('現金', '盗賊'),
#  ('あまり', '盗賊'),
#  ('せめても', '盗賊'),
#  ('殺す', '盗賊'),
#  ('こと', '盗賊'),
#  ('する', '盗賊'),
#  ('宝石', '盗賊'),
#  ('しあわせだ', '盗賊'),
#  ('持つ', '盗賊'),
#  ('ひじょうだ', '盗賊'),
#  ('ただ', '盗賊'),
#  ('盗賊', '美しい'),
#  ('品', '盗賊'),
#  ('品物', '盗賊'),
#  ('ざんこくだ', '傷つける'),
#  ('ある', 'ざんこくだ'),
#  ('ざんこくだ', 'ぬすむ'),
#  ('ざんこくだ', 'めずらしい'),
#  ('ざんこくだ', '現金'),
#  ('あまり', 'ざんこくだ'),
#  ('ざんこくだ', 'せめても'),
#  ('ざんこくだ', '殺す'),
#  ('こと', 'ざんこくだ'),
#  ('ざんこくだ', 'する'),
#  ('ざんこくだ', '宝石'),
#  ('ざんこくだ', 'しあわせだ'),
#  ('ざんこくだ', '持つ'),
#  ('ざんこくだ', 'ひじょうだ'),
#  ('ざんこくだ', 'ただ'),
#  ('ざんこくだ', '美しい'),
#  ('ざんこくだ', '品'),
#  ('ざんこくだ', '品物'),
#  ('ある', '傷つける'),
#  ('ぬすむ', '傷つける'),
#  ('めずらしい', '傷つける'),
#  ('傷つける', '現金'),
#  ('あまり', '傷つける'),
#  ('せめても', '傷つける'),
#  ('傷つける', '殺す'),
#  ('こと', '傷つける'),
#  ('する', '傷つける'),
#  ('傷つける', '宝石'),
#  ('しあわせだ', '傷つける'),
#  ('傷つける', '持つ'),
#  ('ひじょうだ', '傷つける'),
#  ('ただ', '傷つける'),
#  ('傷つける', '美しい'),
#  ('傷つける', '品'),
#  ('傷つける', '品物'),
#  ('ある', 'ぬすむ'),
#  ('ある', 'めずらしい'),
#  ('ある', '現金'),
#  ('あまり', 'ある'),
#  ('ある', 'せめても'),
#  ('ある', '殺す'),
#  ('ある', 'こと'),
#  ('ある', 'する'),
#  ('ある', '宝石'),
#  ('ある', 'しあわせだ'),
#  ('ある', '持つ'),
#  ('ある', 'ひじょうだ'),
#  ('ある', 'ただ'),
#  ('ある', '美しい'),
#  ('ある', '品'),
#  ('ある', '品物'),
#  ('ぬすむ', 'めずらしい'),
#  ('ぬすむ', '現金'),
#  ('あまり', 'ぬすむ'),
#  ('せめても', 'ぬすむ'),
#  ('ぬすむ', '殺す'),
#  ('こと', 'ぬすむ'),
#  ('する', 'ぬすむ'),
#  ('ぬすむ', '宝石'),
#  ('しあわせだ', 'ぬすむ'),
#  ('ぬすむ', '持つ'),
#  ('ぬすむ', 'ひじょうだ'),
#  ('ただ', 'ぬすむ'),
#  ('ぬすむ', '美しい'),
#  ('ぬすむ', '品'),
#  ('ぬすむ', '品物'),
#  ('めずらしい', '現金'),
#  ('あまり', 'めずらしい'),
#  ('せめても', 'めずらしい'),
#  ('めずらしい', '殺す'),
#  ('こと', 'めずらしい'),
#  ('する', 'めずらしい'),
#  ('めずらしい', '宝石'),
#  ('しあわせだ', 'めずらしい'),
#  ('めずらしい', '持つ'),
#  ('ひじょうだ', 'めずらしい'),
#  ('ただ', 'めずらしい'),
#  ('めずらしい', '美しい'),
#  ('めずらしい', '品'),
#  ('めずらしい', '品物'),
#  ('あまり', '現金'),
#  ('せめても', '現金'),
#  ('殺す', '現金'),
#  ('こと', '現金'),
#  ('する', '現金'),
#  ('宝石', '現金'),
#  ('しあわせだ', '現金'),
#  ('持つ', '現金'),
#  ('ひじょうだ', '現金'),
#  ('ただ', '現金'),
#  ('現金', '美しい'),
#  ('品', '現金'),
#  ('品物', '現金'),
#  ('あまり', 'せめても'),
#  ('あまり', '殺す'),
#  ('あまり', 'こと'),
#  ('あまり', 'する'),
#  ('あまり', '宝石'),
#  ('あまり', 'しあわせだ'),
#  ('あまり', '持つ'),
#  ('あまり', 'ひじょうだ'),
#  ('あまり', 'ただ'),
#  ('あまり', '美しい'),
#  ('あまり', '品'),
#  ('あまり', '品物'),
#  ('せめても', '殺す'),
#  ('こと', 'せめても'),
#  ('する', 'せめても'),
#  ('せめても', '宝石'),
#  ('しあわせだ', 'せめても'),
#  ('せめても', '持つ'),
#  ('せめても', 'ひじょうだ'),
#  ('せめても', 'ただ'),
#  ('せめても', '美しい'),
#  ('せめても', '品'),
#  ('せめても', '品物'),
#  ('こと', '殺す'),
#  ('する', '殺す'),
#  ('宝石', '殺す'),
#  ('しあわせだ', '殺す'),
#  ('持つ', '殺す'),
#  ('ひじょうだ', '殺す'),
#  ('ただ', '殺す'),
#  ('殺す', '美しい'),
#  ('品', '殺す'),
#  ('品物', '殺す'),
#  ('こと', 'する'),
#  ('こと', '宝石'),
#  ('こと', 'しあわせだ'),
#  ('こと', '持つ'),
#  ('こと', 'ひじょうだ'),
#  ('こと', 'ただ'),
#  ('こと', '美しい'),
#  ('こと', '品'),
#  ('こと', '品物'),
#  ('する', '宝石'),
#  ('しあわせだ', 'する'),
#  ('する', '持つ'),
#  ('する', 'ひじょうだ'),
#  ('する', 'ただ'),
#  ('する', '美しい'),
#  ('する', '品'),
#  ('する', '品物'),
#  ('しあわせだ', '宝石'),
#  ('宝石', '持つ'),
#  ('ひじょうだ', '宝石'),
#  ('ただ', '宝石'),
#  ('宝石', '美しい'),
#  ('品', '宝石'),
#  ('品物', '宝石'),
#  ('しあわせだ', '持つ'),
#  ('しあわせだ', 'ひじょうだ'),
#  ('しあわせだ', 'ただ'),
#  ('しあわせだ', '美しい'),
#  ('しあわせだ', '品'),
#  ('しあわせだ', '品物'),
#  ('ひじょうだ', '持つ'),
#  ('ただ', '持つ'),
#  ('持つ', '美しい'),
#  ('品', '持つ'),
#  ('品物', '持つ'),
#  ('ただ', 'ひじょうだ'),
#  ('ひじょうだ', '美しい'),
#  ('ひじょうだ', '品'),
#  ('ひじょうだ', '品物'),
#  ('ただ', '美しい'),
#  ('ただ', '品'),
#  ('ただ', '品物'),
#  ('品', '美しい'),
#  ('品物', '美しい'),
#  ('品', '品物'),
#  ('きらいだ', '血'),
#  ('いう', '悪い'),
#  ('いう', 'いくら'),
#  ('いう', '血'),
#  ('いう', '何'),
#  ('いう', 'やつ'),
#  ('あぶない', 'いう'),
#  ('いう', 'こと'),
#  ('いう', 'なる'),
#  ('いう', 'わかる'),
#  ('いう', 'もの'),
#  ('いう', 'のがれる'),
#  ('いう', 'ため'),
#  ('いう', '身'),
#  ('いう', 'する'),
#  ('いう', 'きらいだ'),
#  ('いう', '自分'),
#  ('いくら', '悪い'),
#  ('悪い', '血'),
#  ('何', '悪い'),
#  ('やつ', '悪い'),
#  ('あぶない', '悪い'),
#  ('こと', '悪い'),
#  ('なる', '悪い'),
#  ('わかる', '悪い'),
#  ('もの', '悪い'),
#  ('のがれる', '悪い'),
#  ('ため', '悪い'),
#  ('悪い', '身'),
#  ('する', '悪い'),
#  ('きらいだ', '悪い'),
#  ('悪い', '自分'),
#  ('いくら', '血'),
#  ('いくら', '何'),
#  ('いくら', 'やつ'),
#  ('あぶない', 'いくら'),
#  ('いくら', 'こと'),
#  ('いくら', 'なる'),
#  ('いくら', 'わかる'),
#  ('いくら', 'もの'),
#  ('いくら', 'のがれる'),
#  ('いくら', 'ため'),
#  ('いくら', '身'),
#  ('いくら', 'する'),
#  ('いくら', 'きらいだ'),
#  ('いくら', '自分'),
#  ('何', '血'),
#  ('やつ', '血'),
#  ('あぶない', '血'),
#  ('こと', '血'),
#  ('なる', '血'),
#  ('わかる', '血'),
#  ('もの', '血'),
#  ('のがれる', '血'),
#  ('ため', '血'),
#  ('血', '身'),
#  ('する', '血'),
#  ('きらいだ', '血'),
#  ('自分', '血'),
#  ('やつ', '何'),
#  ('あぶない', '何'),
#  ('こと', '何'),
#  ('なる', '何'),
#  ('わかる', '何'),
#  ('もの', '何'),
#  ('のがれる', '何'),
#  ('ため', '何'),
#  ('何', '身'),
#  ('する', '何'),
#  ('きらいだ', '何'),
#  ('何', '自分'),
#  ('あぶない', 'やつ'),
#  ('こと', 'やつ'),
#  ('なる', 'やつ'),
#  ('やつ', 'わかる'),
#  ('もの', 'やつ'),
#  ('のがれる', 'やつ'),
#  ('ため', 'やつ'),
#  ('やつ', '身'),
#  ('する', 'やつ'),
#  ('きらいだ', 'やつ'),
#  ('やつ', '自分'),
#  ('あぶない', 'こと'),
#  ('あぶない', 'なる'),
#  ('あぶない', 'わかる'),
#  ('あぶない', 'もの'),
#  ('あぶない', 'のがれる'),
#  ('あぶない', 'ため'),
#  ('あぶない', '身'),
#  ('あぶない', 'する'),
#  ('あぶない', 'きらいだ'),
#  ('あぶない', '自分'),
#  ('こと', 'なる'),
#  ('こと', 'わかる'),
#  ('こと', 'もの'),
#  ('こと', 'のがれる'),
#  ('こと', 'ため'),
#  ('こと', '身'),
#  ('こと', 'する'),
#  ('きらいだ', 'こと'),
#  ('こと', '自分'),
#  ('なる', 'わかる'),
#  ('なる', 'もの'),
#  ('なる', 'のがれる'),
#  ('ため', 'なる'),
#  ('なる', '身'),
#  ('する', 'なる'),
#  ('きらいだ', 'なる'),
#  ('なる', '自分'),
#  ('もの', 'わかる'),
#  ('のがれる', 'わかる'),
#  ('ため', 'わかる'),
#  ('わかる', '身'),
#  ('する', 'わかる'),
#  ('きらいだ', 'わかる'),
#  ('わかる', '自分'),
#  ('のがれる', 'もの'),
#  ('ため', 'もの'),
#  ('もの', '身'),
#  ('する', 'もの'),
#  ('きらいだ', 'もの'),
#  ('もの', '自分'),
#  ('ため', 'のがれる'),
#  ('のがれる', '身'),
#  ('する', 'のがれる'),
#  ('きらいだ', 'のがれる'),
#  ('のがれる', '自分'),
#  ('ため', '身'),
#  ('する', 'ため'),
#  ('きらいだ', 'ため'),
#  ('ため', '自分'),
#  ('する', '身'),
#  ('きらいだ', '身'),
#  ('自分', '身'),
#  ('きらいだ', 'する'),
#  ('する', '自分'),
#  ('きらいだ', '自分'),
#  ('いう', '東京'),
#  ('しかたがない', '東京'),
#  ('の', '東京'),
#  ('じつは', '東京'),
#  ('こわい', '東京'),
#  ('人', '東京'),
#  ('うわさ', '東京'),
#  ('東京', '面相'),
#  ('二十', '東京'),
#  ('する', '東京'),
#  ...]

# %%
# """
ct = collections.Counter(target_combinations)
ct.most_common()[:10]
### """
# Out:
# [(('二十', '面相'), 130),
#  (('いう', 'する'), 112),
#  (('こと', 'する'), 108),
#  (('二', '十面相'), 107),
#  (('する', '賊'), 79),
#  (('する', '明智'), 74),
#  (('ある', 'する'), 66),
#  (('ある', 'こと'), 64),
#  (('探偵', '明智'), 63),
#  (('いう', 'こと'), 61)]

# %% [markdown]
# ## 共起ネットワークの描画

# %%
# pyvis インストール
#!pip install pyvis
# Out:
# Collecting pyvis
#   Downloading pyvis-0.1.9-py3-none-any.whl (23 kB)
# Requirement already satisfied: jinja2>=2.9.6 in /opt/conda/lib/python3.9/site-packages (from pyvis) (3.0.1)
# Requirement already satisfied: ipython>=5.3.0 in /opt/conda/lib/python3.9/site-packages (from pyvis) (7.25.0)
# Collecting jsonpickle>=1.4.1
#   Downloading jsonpickle-2.0.0-py2.py3-none-any.whl (37 kB)
# Requirement already satisfied: networkx>=1.11 in /opt/conda/lib/python3.9/site-packages (from pyvis) (2.3)
# Requirement already satisfied: pygments in /opt/conda/lib/python3.9/site-packages (from ipython>=5.3.0->pyvis) (2.9.0)
# Requirement already satisfied: pexpect>4.3 in /opt/conda/lib/python3.9/site-packages (from ipython>=5.3.0->pyvis) (4.8.0)
# Requirement already satisfied: pickleshare in /opt/conda/lib/python3.9/site-packages (from ipython>=5.3.0->pyvis) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /opt/conda/lib/python3.9/site-packages (from ipython>=5.3.0->pyvis) (5.0.5)
# Requirement already satisfied: jedi>=0.16 in /opt/conda/lib/python3.9/site-packages (from ipython>=5.3.0->pyvis) (0.18.0)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.9/site-packages (from ipython>=5.3.0->pyvis) (5.0.9)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /opt/conda/lib/python3.9/site-packages (from ipython>=5.3.0->pyvis) (3.0.19)
# Requirement already satisfied: backcall in /opt/conda/lib/python3.9/site-packages (from ipython>=5.3.0->pyvis) (0.2.0)
# Requirement already satisfied: setuptools>=18.5 in /opt/conda/lib/python3.9/site-packages (from ipython>=5.3.0->pyvis) (49.6.0.post20210108)
# Requirement already satisfied: matplotlib-inline in /opt/conda/lib/python3.9/site-packages (from ipython>=5.3.0->pyvis) (0.1.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /opt/conda/lib/python3.9/site-packages (from jedi>=0.16->ipython>=5.3.0->pyvis) (0.8.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.9/site-packages (from jinja2>=2.9.6->pyvis) (2.0.1)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/conda/lib/python3.9/site-packages (from pexpect>4.3->ipython>=5.3.0->pyvis) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.3.0->pyvis) (0.2.5)
# Requirement already satisfied: ipython-genutils in /opt/conda/lib/python3.9/site-packages (from traitlets>=4.2->ipython>=5.3.0->pyvis) (0.2.0)
# Installing collected packages: jsonpickle, pyvis
# Successfully installed jsonpickle-2.0.0 pyvis-0.1.9

# %%
# ネットワーク描画のメイン処理定義
def kyoki_word_network():
    from pyvis.network import Network

    got_net = Network(height="1000px", width="100%", bgcolor="#222222", font_color="white", notebook=True)

    # スムーズ化
    got_net.set_edge_smooth('continuous')

    # set the physics layout of the network
    #got_net.barnes_hut()
    got_net.force_atlas_2based()
    got_data = pd.read_csv("kyoki.csv")[:target_num]

    sources = got_data['first']#count
    targets = got_data['second']#first
    weights = got_data['count']#second

    edge_data = zip(sources, targets, weights)

    for i, e in enumerate(edge_data):
        src = e[0]
        dst = e[1]
        w = e[2]

        got_net.add_node(src, src, title=src, group=i)
        got_net.add_node(dst, dst, title=dst, group=i)
        got_net.add_edge(src, dst, value=w)

    neighbor_map = got_net.get_adj_list()

    # add neighbor data to node hover data
    for node in got_net.nodes:
        node["title"] += " Neighbors:<br>" + "<br>".join(neighbor_map[node["id"]])
        node["value"] = len(neighbor_map[node["id"]])

    # got_net.show_buttons(filter_=['physics', 'nodes'])
    return got_net

    #got_net.show("gameofthrones.html")

# %%
# 所定の構造でCSVファイルに出力
pd.DataFrame([{'first' : i[0][0], 'second' : i[0][1], 'count' : i[1]} for i in ct.most_common()]).to_csv('kyoki.csv', index=False)

# %%
# 処理の実行
got_net = kyoki_word_network()
got_net.show(f'{file_name}_{hinshi_name}_{target_num}.html')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipykernel_32/1821067264.py in <module>
#       1 # 処理の実行
# ----> 2 got_net = kyoki_word_network()
#       3 got_net.show(f'{file_name}_{hinshi_name}_{target_num}.html')
#
# /tmp/ipykernel_32/249375411.py in kyoki_word_network()
#       1 # ネットワーク描画のメイン処理定義
#       2 def kyoki_word_network():
# ----> 3     from pyvis.network import Network
#       4
#       5     got_net = Network(height="1000px", width="100%", bgcolor="#222222", font_color="white", notebook=True)
#
# /opt/conda/lib/python3.9/site-packages/pyvis/__init__.py in <module>
# ----> 1 from . import network
#       2 from ._version import __version__
#
# /opt/conda/lib/python3.9/site-packages/pyvis/network.py in <module>
#       8 from IPython.core.display import HTML
#       9 from collections import defaultdict
# ---> 10 import networkx as nx
#      11 import json
#      12 import jsonpickle
#
# /opt/conda/lib/python3.9/site-packages/networkx/__init__.py in <module>
#     112 from networkx.relabel import *
#     113
# --> 114 import networkx.generators
#     115 from networkx.generators import *
#     116
#
# /opt/conda/lib/python3.9/site-packages/networkx/generators/__init__.py in <module>
#      12 from networkx.generators.expanders import *
#      13 from networkx.generators.geometric import *
# ---> 14 from networkx.generators.intersection import *
#      15 from networkx.generators.joint_degree_seq import *
#      16 from networkx.generators.lattice import *
#
# /opt/conda/lib/python3.9/site-packages/networkx/generators/intersection.py in <module>
#      11 import random
#      12 import networkx as nx
# ---> 13 from networkx.algorithms import bipartite
#      14 from networkx.utils import py_random_state
#      15
#
# /opt/conda/lib/python3.9/site-packages/networkx/algorithms/__init__.py in <module>
#      14 from networkx.algorithms.cycles import *
#      15 from networkx.algorithms.cuts import *
# ---> 16 from networkx.algorithms.dag import *
#      17 from networkx.algorithms.distance_measures import *
#      18 from networkx.algorithms.distance_regular import *
#
# /opt/conda/lib/python3.9/site-packages/networkx/algorithms/dag.py in <module>
#      21
#      22 from collections import defaultdict, deque
# ---> 23 from fractions import gcd
#      24 from functools import partial
#      25 from itertools import chain
#
# ImportError: cannot import name 'gcd' from 'fractions' (/opt/conda/lib/python3.9/fractions.py)

# %%
# !pip list
# Out:
# Package                       Version
# ----------------------------- -------------------
# alembic                       1.6.5
# altair                        4.1.0
# anyio                         3.2.1
# appdirs                       1.4.4
# argon2-cffi                   20.1.0
# async-generator               1.10
# attrs                         21.2.0
# Babel                         2.9.1
# backcall                      0.2.0
# backports.functools-lru-cache 1.6.4
# beautifulsoup4                4.9.3
# bleach                        3.3.0
# blinker                       1.4
# bokeh                         2.3.2
# Bottleneck                    1.3.2
# brotlipy                      0.7.0
# cached-property               1.5.2
# certifi                       2021.5.30
# certipy                       0.1.3
# cffi                          1.14.5
# chardet                       4.0.0
# click                         8.0.1
# cloudpickle                   1.6.0
# conda                         4.10.2
# conda-package-handling        1.7.3
# cryptography                  3.4.7
# cycler                        0.10.0
# Cython                        0.29.23
# cytoolz                       0.11.0
# dask                          2021.6.2
# debugpy                       1.3.0
# decorator                     5.0.9
# defusedxml                    0.7.1
# dill                          0.3.4
# distributed                   2021.6.2
# entrypoints                   0.3
# fsspec                        2021.6.1
# gmpy2                         2.1.0b5
# greenlet                      1.1.0
# h5py                          3.3.0
# HeapDict                      1.0.1
# idna                          2.10
# imagecodecs                   2021.6.8
# imageio                       2.9.0
# importlib-metadata            4.6.0
# ipykernel                     6.0.1
# ipympl                        0.7.0
# ipython                       7.25.0
# ipython-genutils              0.2.0
# ipywidgets                    7.6.3
# jedi                          0.18.0
# Jinja2                        3.0.1
# joblib                        1.0.1
# json5                         0.9.5
# jsonpickle                    2.0.0
# jsonschema                    3.2.0
# jupyter-client                6.1.12
# jupyter-core                  4.7.1
# jupyter-server                1.9.0
# jupyter-telemetry             0.1.0
# jupyterhub                    1.4.1
# jupyterlab                    3.0.16
# jupyterlab-pygments           0.1.2
# jupyterlab-server             2.6.0
# jupyterlab-widgets            1.0.0
# kiwisolver                    1.3.1
# llvmlite                      0.36.0
# locket                        0.2.0
# Mako                          1.1.4
# mamba                         0.14.1
# MarkupSafe                    2.0.1
# matplotlib                    3.4.2
# matplotlib-inline             0.1.2
# mistune                       0.8.4
# mock                          4.0.3
# mpmath                        1.2.1
# msgpack                       1.0.2
# nbclassic                     0.3.1
# nbclient                      0.5.3
# nbconvert                     6.1.0
# nbformat                      5.1.3
# nest-asyncio                  1.5.1
# networkx                      2.3
# notebook                      6.4.0
# numba                         0.53.1
# numexpr                       2.7.3
# numpy                         1.21.0
# oauthlib                      3.1.1
# olefile                       0.46
# packaging                     20.9
# pamela                        1.0.0
# pandas                        1.3.0
# pandocfilters                 1.4.2
# parso                         0.8.2
# partd                         1.2.0
# patsy                         0.5.1
# pexpect                       4.8.0
# pickleshare                   0.7.5
# Pillow                        8.3.0
# pip                           21.1.3
# pooch                         1.4.0
# prometheus-client             0.11.0
# prompt-toolkit                3.0.19
# protobuf                      3.17.2
# psutil                        5.8.0
# ptyprocess                    0.7.0
# pycosat                       0.6.3
# pycparser                     2.20
# pycurl                        7.43.0.6
# Pygments                      2.9.0
# PyJWT                         2.1.0
# pyOpenSSL                     20.0.1
# pyparsing                     2.4.7
# pyrsistent                    0.17.3
# PySocks                       1.7.1
# python-dateutil               2.8.1
# python-editor                 1.0.4
# python-json-logger            2.0.1
# pytz                          2021.1
# pyvis                         0.1.9
# PyWavelets                    1.1.1
# PyYAML                        5.4.1
# pyzmq                         22.1.0
# requests                      2.25.1
# requests-unixsocket           0.2.0
# ruamel-yaml-conda             0.15.80
# ruamel.yaml                   0.17.10
# ruamel.yaml.clib              0.2.2
# scikit-image                  0.18.1
# scikit-learn                  0.24.2
# scipy                         1.7.0
# seaborn                       0.11.1
# Send2Trash                    1.7.1
# setuptools                    49.6.0.post20210108
# six                           1.16.0
# sniffio                       1.2.0
# sortedcontainers              2.4.0
# soupsieve                     2.0.1
# SQLAlchemy                    1.4.20
# statsmodels                   0.12.2
# sympy                         1.8
# tables                        3.6.1
# tblib                         1.7.0
# terminado                     0.10.1
# testpath                      0.5.0
# threadpoolctl                 2.1.0
# tifffile                      2021.6.14
# toolz                         0.11.1
# tornado                       6.1
# tqdm                          4.61.1
# traitlets                     5.0.5
# typing-extensions             3.10.0.0
# urllib3                       1.26.6
# wcwidth                       0.2.5
# webencodings                  0.5.1
# websocket-client              0.57.0
# wheel                         0.36.2
# widgetsnbextension            3.5.1
# xlrd                          2.0.1
# zict                          2.0.0
# zipp                          3.4.1

# %% [markdown]
# ## まとめて作成

# %%
# """
for name, file in novels.values:
    sakuhin_name = name
    target_hinshi = ['名詞', '形容詞', '副詞', '動詞']
    hinshi_name = ''
    target_num = 250

    if target_hinshi == ['名詞']:
        hinshi_name = 'meishi'
    elif target_hinshi == ['形容詞']:
        hinshi_name = 'keiyoushi'
    elif target_hinshi == ['副詞']:
        hinshi_name = 'fukushi'
    elif target_hinshi == ['動詞']:
        hinshi_name = 'doushi'
    else:
        hinshi_name = 'all'
        target_num = 1000

    # file_name = list(novels.query(' name == @sakuhin_name ')['file_name'])[0]
    file_name = file
    df = pd.read_csv(f'csv/df/{file_name}.csv')

    midashi = list(df['見出し'])
    genkei = list(df['原型'])
    hinshi = list(df['品詞'])
    sentences = []
    for i in range(len(midashi)):
        sentences.append([midashi[i], genkei[i], hinshi[i]])

    keywords = []
    words = []
    for sentence in sentences:
        if sentence[0] != '。':
            if sentence[2] in target_hinshi:
                words.append(sentence[1])
        else:
            keywords.append(words)
            words = []

    sentence_combinations = [list(itertools.combinations(set(sentence), 2)) for sentence in keywords]
    sentence_combinations = [[tuple(sorted(words)) for words in sentence] for sentence in sentence_combinations]
    target_combinations = []
    for sentence in sentence_combinations:
        target_combinations.extend(sentence)

    ct = collections.Counter(target_combinations)

    # 所定の構造でCSVファイルに出力
    pd.DataFrame([{'first' : i[0][0], 'second' : i[0][1], 'count' : i[1]} for i in ct.most_common()]).to_csv('kyoki.csv', index=False)

    try:
        # 処理の実行
        got_net = kyoki_word_network()
        got_net.show(f'static/{file_name}_{hinshi_name}_{target_num}.html')
        time.sleep(2)
    except:
        print(f'作品名：{name}, 対象の品詞：{file}, 上位共起数：{target_num}')
        continue

### """
